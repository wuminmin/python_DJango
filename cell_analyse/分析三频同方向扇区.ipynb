# %%
import traceback
from math import nan

import numpy as np
import pandas as pd
import time
df1 = pd.read_excel('LTE扇区导出_20190218_142125_42351.xlsx')
df1_columns_name_lsit = df1.columns.tolist()
print(df1_columns_name_lsit)
# Out:
# ['状态', '省/自治区/直辖市', '市/地区/州/盟', '区/市/县/旗', '区（街道）/乡/镇', '网格编号', '归属营业部名称', '归属包区', '物理站点名称', '工程站号', '基站标识eNodeBID', '基站中文名', '小区标识CellID', '扇区中文名', '扇区拼音', '扇区经度', '扇区纬度', '扇区号SectorID', '本地小区标识Local CellID', '索引关键值（ECI）', 'C网索引关键值', '扇区地址', '是否同PCI小区', '同PCI小区编号', '是否级联小区', '级联小区编号', '是否功分扇区', '功分扇区编号', '是否BBU池', '归属BBU池名称', '扇区覆盖区域类型', '扇区覆盖道路类型', '扇区覆盖热点类型', '业务类型', '覆盖高校信息', '覆盖高铁信息', '覆盖高速信息', '覆盖高密度住宅信息', '覆盖高流量商务区信息', '覆盖地铁信息', '扇区类别', '扇区状态', '系统类型', '站点类型', '设备产权', '设备是否共享', '共建共享方式', 'RRU设备型号', '设备厂家', '入网日期', '天线厂家', '天线型号', '多频天线类型', '小区Tx天线端口数', '小区Rx天线端口数', '天线方位角', '预置电下倾角', '可调电下倾角', '电子倾角', '机械物理倾角', '总下倾角', '是否可变电调', '天线所在平台', '天线挂高', '天线方向类型', '天线极化方式', '天线增益', '天线水平半功率角', '天线垂直半功率角', '是否美化天线', '美化天线类型', '物理小区PCI', 'TAL', 'TAC', '频段指示', '上行中心频点', '下行中心频点', '上行带宽', '下行带宽', '小区功率(w)', 'ZC根序列', 'TD时隙比例', 'TD特殊时隙配比', '小区高速移动属性', '小区半径（千米）', '载波合路方式', '副RRU型号', '副RRU频段', '扇区机房共享情况', '扇区机房产权方', '塔桅共享情况', '塔桅产权方', '塔桅类型', '扇区海拔高度（m）', '边界扇区类型', '对端省份名称', '对端地市名称', '是否分频待机', '边界小区业务类型', '边界区域类型', '是否校园优惠小区', '带直放站数量', '带室分系统数量', '数据最近更新日期', '数据最后更新人', '备注', '上传图片数', '上传文档数']

# %%
df1.head()
# Out:
#     状态 省/自治区/直辖市 市/地区/州/盟 区/市/县/旗 区（街道）/乡/镇        网格编号  归属营业部名称   归属包区  \
# 0  NaN       安徽省      宣城市     宣州区       水阳镇  AH-XC-0052  水阳农村营业部  宣州区包区
# 1  NaN       安徽省      宣城市     宣州区       水阳镇  AH-XC-0052  水阳农村营业部  宣州区包区
# 2  NaN       安徽省      宣城市     广德县       卢村乡  AH-XC-0001  柏垫农村营业部  广德县包区
# 3  NaN       安徽省      宣城市     广德县       卢村乡  AH-XC-0001  柏垫农村营业部  广德县包区
# 4  NaN       安徽省      宣城市     广德县       卢村乡  AH-XC-0001  柏垫农村营业部  广德县包区
#
#          物理站点名称                  工程站号  ...   边界小区业务类型 边界区域类型  是否校园优惠小区 带直放站数量  \
# 0  XC-宣州区-双盈-自建     F-XC-16-0170-R-RW  ...     省际普通用户      无         否      0
# 1  XC-宣州区-双盈-自建     F-XC-16-0170-R-RW  ...     省际普通用户      无         否      0
# 2    XC-广德-广德四合  F-XC-16-0051-R-RW-TT  ...          无      无         否      0
# 3    XC-广德-广德四合  F-XC-16-0051-R-RW-TT  ...          无      无         否      0
# 4    XC-广德-广德四合  F-XC-16-0051-R-RW-TT  ...          无      无         否      0
#
#   带室分系统数量    数据最近更新日期  数据最后更新人   备注  上传图片数 上传文档数
# 0       0  2019-02-18      NaN  NaN      0     0
# 1       0  2019-02-18      NaN  NaN      0     0
# 2       0  2019-02-18      NaN  NaN      0     0
# 3       0  2019-02-18      NaN  NaN      0     0
# 4       0  2019-02-18      NaN  NaN      0     0
#
# [5 rows x 108 columns]

# %%
from gmplot import gmplot

# Place map
gmap = gmplot.GoogleMapPlotter(37.766956, -122.438481, 13)

# Polygon
golden_gate_park_lats, golden_gate_park_lons = zip(*[
    (37.771269, -122.511015),
    (37.773495, -122.464830),
    (37.774797, -122.454538),
    (37.771988, -122.454018),
    (37.773646, -122.440979),
    (37.772742, -122.440797),
    (37.771096, -122.453889),
    (37.768669, -122.453518),
    (37.766227, -122.460213),
    (37.764028, -122.510347),
    (37.771269, -122.511015)
    ])
gmap.plot(golden_gate_park_lats, golden_gate_park_lons, 'cornflowerblue', edge_width=10)

# Scatter points
top_attraction_lats, top_attraction_lons = zip(*[
    (37.769901, -122.498331),
    (37.768645, -122.475328),
    (37.771478, -122.468677),
    (37.769867, -122.466102),
    (37.767187, -122.467496),
    (37.770104, -122.470436)
    ])
gmap.scatter(top_attraction_lats, top_attraction_lons, '#3B0B39', size=40, marker=False)

# Marker
hidden_gem_lat, hidden_gem_lon = 37.770776, -122.461689
gmap.marker(hidden_gem_lat, hidden_gem_lon, 'cornflowerblue')

# Draw
gmap.draw("my_map.html")
